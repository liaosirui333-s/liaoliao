# %% [markdown]
# i really dont have a habit of tracking personal data,,,, and at this point of the semaster
# i dont really have time to start one,,,,,,,,, (╯﹏╰）
# so i fed it the novel Nausea by Satre, so it could write like the main charater Antoine Roquentin that suffers from existenial nausea. it is quite fun to read an ai's diary.
#
# thank isabella for sharing the api keyyyyyy （＾ν＾）

# %%
#data frame, diary by date

import pandas as pd
import numpy as np
df = pd.read_csv('nausea.csv', dtype=object)
df
# Out:
#            prompt                                         completion
# 0   Undated Sheet  The best thing would be to write down everythi...
# 1        19320129  Something has happened to me: I can’t doubt th...
# 2        19320130  Nothing new.\nI worked from nine till one in t...
# 3        19320203  A little while ago, going down the hotel stair...
# 4        19320203  "M. de Rollebon was quite ugly. Queen Marie An...
# 5        19320204  Three o'clock. Three o'clock is always too lat...
# 6        19320204  Things are bad! Things are very bad: I have it...
# 7        19320204  I have worked two hours in the reading-room. I...
# 8        19320205  I have given up Eugenie Grandet and begun work...
# 9        19320205  A little more and I would have fallen into the...
# 10       19320206  The Self-Taught Man did not see me come into t...
# 11       19320207  I had forgotten that this morning was Sunday. ...
# 12       19320208  How could I have written that pompous, absurd ...
# 13       19320209  Work today. It didn't go too badly; I wrote si...
# 14       19320210  I gave Maurice Barres a spanking. We were thre...
# 15       19320211                               I must not be afraid
# 16       19320212  Four pages written. Then a long moment of happ...
# 17       19320213  The fog was so thick on the Boulevard de la Re...
# 18       19320214  urday morning:\nA charming sun with a light mi...
# 19       19320215  I'm not writing my book on Rollebon any more; ...
# 20       19320216                                   Nothing. Existed
# 21       19320217  There is a sunbeam on the paper napkin. In the...
# 22       19320217  A fine climax: it shakes me from top to bottom...
# 23       19320218  I can't say I feel relieved or satisfied; just...
# 24       19320218  I have made my decision: I have no more reason...
# 25       19320219  In the "Railwaymen's Rendezvous." My train lea...
# 26       19320220  Anny opens to me in a long black dress. Natura...
# 27       19320221  "I have a sort of ... physical certainty. I fe...
# 28       19320222  This morning I consulted the Railway Guide: as...
# 29       19320224  Is that what freedom is? Below me, the gardens...
# 30       19320225  Wednesday: My last day in Bouville:\nI have lo...

# %%
openai.api_key = "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"

import openai

response = openai.Completion.create(
    model="curie:ft-personal-2023-04-12-05-53-09",
    prompt="19320130",
    temperature=0.4, #randomness 
    max_tokens=200, #charaters in response 
    top_p=1, #controls diversity
    frequency_penalty=0, #decrease repetition 
    presence_penalty=1 #increase likelihood to talk about new topic 
)

# %%
result = response.choices[0].text
print(result)
# Out:
# . I'm going to see the doctor.
# I have to tell him everything, everything that has happened since I came back from Paris. I must not leave anything out. I mustn't be afraid of what he might say or do. I mustn't think about that. I mustn't be afraid of anything. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid. I mustn't let myself be afraid

# %%
response = openai.Completion.create(
    model="curie:ft-personal-2023-04-12-05-53-09",
    prompt="19320130",
    temperature=0.5, #randomness 
    max_tokens=300, #charaters in response 
    top_p=1, #controls diversity
    frequency_penalty=0, #decrease repetition 
    presence_penalty=0.5 #increase likelihood to talk about new topic 
)
result = response.choices[0].text
print(result)
# Out:
# . The fight was over. I felt quite calm. I had done my duty. I had fought, I had beaten the man. I had not killed him, but I had not let him kill me. And the man was dead.
# I looked at his face, which was almost touching mine. I felt no pity for him. He was a brute, he had deserved to be killed. But I felt nothing, I was empty.
# I got up and washed my hands. I felt very dirty. I took out of my pocket the four letters I had written at Bouville. I felt a little ashamed of them. I threw them into the stove. Then I went out.
# The sun was shining. The wind was blowing. The sea was still. There were no ships in sight. It was a fine day.
# I walked along the edge of the sea. I looked at the water, then I looked at the sky. I felt a little afraid.
# I came back to the inn. I took a bath and went to bed.
# I could not sleep. I lay there without thinking. I heard the sea beating against the shore. I heard the wind blowing outside the window. I thought of the man I had killed. I thought of the woman I had let escape. I thought of the four letters I had thrown into the stove before leaving Bouville. I thought of the man who was lying in the gutter, of the woman who had laughed at

# %%
response = openai.Completion.create(
    model="curie:ft-personal-2023-04-12-05-53-09",
    prompt="19320230",
    temperature=0.5, #randomness 
    max_tokens=300, #charaters in response 
    top_p=1, #controls diversity
    frequency_penalty=0, #decrease repetition 
    presence_penalty=0.5 #increase likelihood to talk about new topic 
)
result = response.choices[0].text
print(result)
# Out:
# 33. The door was open and a man was standing there. He was wearing a light-coloured overcoat and he had a black hat on his head. He was looking at me with an air of surprise. I thought he must have been asleep and that he was surprised to see me there. He took his hat off and put it on the table. I went up to him and said:
# "I am going to leave you. I am going to live in Paris."
# He did not answer. He was looking at me in a curious way. I felt a little frightened. I said:
# "I must go. Goodbye."
# He looked at me, then he took his hat off and put it on again. Then he began to laugh. I was very much embarrassed. I did not know what to do. I was afraid he would laugh at me. I wanted to laugh too. But I was afraid of being laughed at. I only understood that he was laughing at my saying "goodbye". I left the cafe and went down the Rue des Beaux-Arts.
# I walked fast, thinking of nothing. When I stopped in front of the Hotel de Bourges I felt hungry. I had a good dinner and then I went to sleep
# At five o'clock in the morning I got up. I washed and dressed. At eight o'clock I was in the Gare Saint-Lazare. I took the train for Orlé

# %%
response = openai.Completion.create(
    model="curie:ft-personal-2023-04-12-05-53-09",
    prompt="19320202",
    temperature=0.5, #randomness 
    max_tokens=500, #charaters in response 
    top_p=1, #controls diversity
    frequency_penalty=0, #decrease repetition 
    presence_penalty=0.6 #increase likelihood to talk about new topic 
)
result = response.choices[0].text
print(result)
# Out:
# , the only thing I did wrong was to go to the bar by myself. I should have gone with Lilou, who would have made me laugh.
# I can see her now, in front of her mirror, with her hair in a ponytail and her false eyelashes. She's putting on her lipstick, and I'm leaning against the wall, watching her.
# I don't know why I'm so fond of her. Maybe it's because she never asks anything of me. She doesn't make any demands on me, she doesn't want anything from me. With all her heart she loves me, that's clear, but she doesn't give me any reason to love her; she doesn't bother me.
# And yet I'm crazy about her.
# When I look at her, I feel like kissing her, or maybe just holding her in my arms for a minute. But I don't do it, I don't dare. END OF PART ONE END OF THE EPISODE I END OF THE BOOK
# I END OF THE PAST
# I END OF THE WORLD

# %% [markdown]
# ~(';')~
